# %% [markdown]
# 1. What are data structures and why are they important?

# %% [markdown]
# Data structures are specialized formats for organizing, processing, and storing data. They define how data is arranged in memory and how operations like access, insertion, deletion, and traversal are performed.
# Common types include:
# - Lists: Ordered collections of items
# - Tuples: Immutable sequences
# - Dictionaries: Key-value pairs
# - Sets: Unordered collections of unique items
#
# Efficient Data Management:
# They help organize and store data in ways that make it easy to access, modify, and process—especially when dealing with large or complex datasets.
# Performance Optimization:
# Choosing the right data structure can drastically improve the speed and memory usage of your program. For example, dictionaries allow fast lookups, while lists are great for ordered data.
# Simplified Problem Solving:
# Many algorithms rely on specific data structures (like stacks, queues, or trees) to work correctly. Understanding them helps you design better solutions.
# Code Readability and Maintainability:
# Well-chosen data structures make your code cleaner, easier to understand, and simpler to maintain.

# %% [markdown]
# 2.Explain the difference between mutable and immutable data types.
#
# - Mutable data type: These are data types whose content can be changed after they are created.
#    When you modify a mutable object, you’re changing the original object itself.
#
# Immutable data Type:- These are data types whose content cannot be changed once they are created.
# Any operation that seems to modify an immutable object actually creates a new object.

# %% [markdown]
# 3. What are the main differences between list and tuple
# --> The main difference between list and tuple is that a list is mutable meaning its elements can be changed, added or removed after creation, while a tuple is immutable, meaning its contents cannot be modified once defined.
# ---> list are generally slower than tuples because they allow more opeartions and use more memory while tuples are faster and more memory effiecient.

# %% [markdown]
# 4. Describe how dictionaries store data
# --> Dictionaries in Python store data in the form of key-value pairs.
# Each value is linked to a unique key, and you can access the value by using its key instead of an index.
# Internally, dictionaries use a data structure called a hash table. When a key is added, Python applies a hash function to the key to generate a unique numbver called a hash value. This hash value determines where the key-value pair is storerd in memory.

# %% [markdown]
# 5. Why might you use a set instead of a list in python?
# -->When you need to store unique elements and don"t Care about the order of elements. sets automatically remove tghe duplicates.

# %% [markdown]
# 6. What is string in Python, and how is it different from a list?
# --> A string is a sequence of characters enclosed in quotes. It is immuttable.
# --> A list, however can store multiple data types and is mutable.

# %% [markdown]
# 7. How do tuples ensure data integrity in python?
# --> Tuples are immutable, so once created their values cannot be altered. This prevents accidental modification, ensuring that the data remains consistent and secure throughout the program.

# %% [markdown]
# 8. What is a hash table, and how does it relate to dictionaries in Python?
# --> A hash table is a data structure that stores data in  key-value pairs using a hash function to compute an index for each key.
#    Python dictionaries are implemented using hash tables to allow fast lookups and updates.

# %% [markdown]
# 9. Can lists contain different data types in Python?
# --> YES, list can contain different dta types such as integers, strings, floats or even other lists and dictionaries.

# %% [markdown]
# 10.Explain why strings are immutable in python.

# %% [markdown]
# 11. What advantages do dictionaries offer over lists for certain tasks?
# --> Dictionaries allow faster data access using leys instead of searching all elements like in lists.They are also better when data is organized in key-value form.

# %% [markdown]
# 12. Describe a scenario where using a tuple would be preferable over a list

# %% [markdown]
# 13. How do sets handle duplicate values in Python?
# --> Sets automatically remove duplicate values. If you try to adda an existing element, it will not be added again.

# %% [markdown]
# 14. How does the "in" keyword work diferently for lists and dictionaries?
# --> In a list, the in keyword checks whether a value exists in the list. In a dictionary, it checks whether a key exists, not the value.

# %% [markdown]
# 15. Can you modify the elements of a tuple? Explain why or why not.
# --> No, you cannot modify the elements of a tuple because tuples are immutable. Once created their contents cannot be changed, added or removed.

# %% [markdown]
# 16. What is nested dictionary, and give an example of its use case?
# --> A nested dictionary is a dictionary inside another dictionary. It is used to store complex data like student records.

# %% [markdown]
# 17. Describe the time complexity of accessing elements in a dictionary.
# -->

# %%
18. In what situations are lists preferred over dictionaries?
--> Lists are preferred when the data is ordered, when you only need to store data values(not key-value pairs), or when the order of elements matters, such as processing a series of numbers.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrival.
# --> A list retrieves elemts by index position, whereas a dictionary retrieves elements by key. Dictionary lookups are faster because they use hashing, while list lookups require searching through elements.

# %% [markdown]
# Practical questions

# %% [markdown]
# 1.Write a code to create a string with your name and print it.

# %%
print("Soniya")
# Out:
# Soniya

# %% [markdown]
# 2. Write a code to find the length of the string "Hello world"

# %%
len("Hello world")
# Out:
# 11

# %% [markdown]
# 3. write a code to slice the first 3 characters from the string "Python Programming"

# %%
a = "Python Programming"
print(a[0:3])
# Out:
# Pyt

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase.

# %%
b = "hello"
c= b.upper()
print(c)
# Out:
# HELLO

# %% [markdown]
# 5. write a code to replace the word "apple" with "orange" in the string "I like apple"

# %%
d= "I like apple"
d.replace("apple","orange")
# Out:
# 'I like orange'

# %% [markdown]
# 6. Write a code to create a list with numbers 1 to 5 and print it.

# %%
list(range(1,6))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 7.write a code to append the number 10 to the list [1,2,3,4]

# %%
x = [1,2,3,4]
x.append(10)
x
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8. Write a code to remove the number 3 from the list [1,2,3,4,5]

# %%
s = [1,2,3,4,5]
s.remove(3)
s
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9. Write the code to access the second element in the list ["a","b","c","d"]

# %%
s = ["a","b","c","d"]
s[1]
# Out:
# 'b'

# %% [markdown]
# 10. Write a code to reverse the list [10, 20, 30, 40, 50]

# %%
s = [10, 20, 30, 40, 50]
s[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11. Write a code to create a tuple with the element 100, 200, 300 and print it

# %%
x = (100,200,300)
print(x, type(x))
# Out:
# (100, 200, 300) <class 'tuple'>

# %% [markdown]
# 12.Write a code to access the second-to-last element of the tuple("red", "green", "blue","yellow")

# %%
x = ("red", "green", "blue","yellow")
x[2]
# Out:
# 'blue'

# %% [markdown]
# 13. Write a code to find the minimun number in the tuple(10, 20, 5, 15)

# %%
x = (10, 20, 5, 15)
min(x)
# Out:
# 5

# %% [markdown]
# 14.Write a code to find the index of the element "Cat" in the tuple("dog", "cat","rabbit")

# %%
x = ("dog", "cat","rabbit") 
index = x.index("cat")
print(index)
# Out:
# 1

# %% [markdown]
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

# %%
s = ("Apple", "Oranges", "Kiwi")
for i in s:
    if i == "Kiwi":
        print(i)
# Out:
# Kiwi

# %% [markdown]
# 16. Write a code to create  a set with the elements "a", "b","c" and print it

# %%
y = ["a", "b", "c"]
y
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# 17. Write a code to clear all the elements from the set {1, 2, 3, 4, 5}

# %%
s = {1,2,3,4,5}
a = s.clear()
type(a)
# Out:
# NoneType

# %% [markdown]
# 18. Write a code to remove the element 4 from the set {1,2,3,4}

# %%
a = {1,2,3,4}
a.remove(4)
print(a)
# Out:
# {1, 2, 3}

# %% [markdown]
# 19. Write a code to remove the union of two sets {1,2,3} and {3,4,5}

# %%
{1,2,3} | {3,4,5}
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 20. Write a code to find the intersection of two sets {1,2,3} and {2,3,4}

# %%
{1,2,3}&{2,3,4}
# Out:
# {2, 3}

# %% [markdown]
# 21.Write a code to create the dictionary with the keys "name", "age" and "city" and print it

# %%
s = {"name": " ", "age": " ", "city": " "}
s
# Out:
# {'name': ' ', 'age': ' ', 'city': ' '}

# %% [markdown]
# 22. Write a code to add a key value pair "country": "USA" to the dictionary {"name":"Alice","age":30}

# %%
d = {"name":"Alice","age":30}

# %%
d["country"]="USA"

# %%
d
# Out:
# {'name': 'Alice', 'age': 30, 'country': 'USA'}

# %% [markdown]
# 23.Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30, 'country': 'USA'}

# %%
f = {'name': 'Alice', 'age': 30, 'country': 'USA'}

# %%
f["name"]
# Out:
# 'Alice'

# %% [markdown]
# 24. Write a code to remove the key "age" from the dictionary {"name":"Bob","Age":"22","city":"New York"}

# %%
s = {"name":"Bob","Age":"22","city":"New York"}

# %%
s.pop("Age")
s
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# 25. Check if key "city" exists in {"name":"Alice", "city":"Paris"}

# %%
t1 = {"name":"Alice", "city":"Paris"}

# %%
print("city" in t1)
# Out:
# True

# %% [markdown]
# 26. Create a list, a tuple, and a dictionary and print them all.

# %%
my_list = [11, 22, 33, 44]
my_tuple = (101, 202, 303)
my_dict = {"Name": "Soniya", "State":"Goa", "Age":27}

# %%
print(my_list, my_tuple, my_dict)
# Out:
# [11, 22, 33, 44] (101, 202, 303) {'Name': 'Soniya', 'State': 'Goa', 'Age': 27}

# %% [markdown]
# 27. Write a code to Create a list of five random numbers between 1 to 100 sort it in  ascending order and print the result.

# %%
import random
random_list = random.sample(range(1, 101), 5)
random_list.sort()
random_list
# Out:
# [13, 25, 37, 63, 65]

# %% [markdown]
# 28. Write a code to create a list with strings and print the element of the third index.

# %%
str_list = ["One", "soniya", "Tilak", "Gujarat"]

# %%
str_list[3]
# Out:
# 'Gujarat'

# %% [markdown]
# 29. Write a code to combine two dictionaries into one and print the result.

# %%
d1 = {"class": "A", "Name": "Soniya"}
d2 = {"Roll No": 10, "Subject": "Data-science"}
d1
# Out:
# {'class': 'A', 'Name': 'Soniya'}

# %%
d2
# Out:
# {'Roll No': 10, 'Subject': 'Data-science'}

# %%
d3 = d1.copy()
d3.update(d2)
d3
# Out:
# {'class': 'A', 'Name': 'Soniya', 'Roll No': 10, 'Subject': 'Data-science'}

# %% [markdown]
# 30. Write a code to convert a list of strings into a set

# %%
list = ["Soniya", "Abhijit", "Tejas", "Abhay"]
a = set(list)
print(a)
# Out:
# {'Soniya', 'Abhay', 'Abhijit', 'Tejas'}
